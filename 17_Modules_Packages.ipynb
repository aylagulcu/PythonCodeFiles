# %% [markdown]
# Modules provide an easy way to organize components into a system
# All the names defined at top level of a module file become attributes of the imported module object

# %%
# import   : Lets a client (importer) fetch a module as a whole
# from     : Allows clients to fetch particular names from a module

# %% [markdown]
# Program structure:
# * One top level script file
# * Multiple module files

# %% [markdown]
# import statement:
# * identifies the external file to be loaded
# * external file becomes a variable assigned to the loaded module

# %%
import sys
sys.modules
# Out:
# {'IPython': <module 'IPython' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/__init__.py'>,
#  'IPython.core': <module 'IPython.core' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/core/__init__.py'>,
#  'IPython.core.alias': <module 'IPython.core.alias' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/core/alias.py'>,
#  'IPython.core.application': <module 'IPython.core.application' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/core/application.py'>,
#  'IPython.core.autocall': <module 'IPython.core.autocall' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/core/autocall.py'>,
#  'IPython.core.builtin_trap': <module 'IPython.core.builtin_trap' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/core/builtin_trap.py'>,
#  'IPython.core.compilerop': <module 'IPython.core.compilerop' from '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/core/compilerop.py'>,
# ...

# %%
sys.path
# Out:
# ['',
#  '/home/ayla/anaconda3/lib/python36.zip',
#  '/home/ayla/anaconda3/lib/python3.6',
#  '/home/ayla/anaconda3/lib/python3.6/lib-dynload',
#  '/home/ayla/anaconda3/lib/python3.6/site-packages',
#  '/home/ayla/anaconda3/lib/python3.6/site-packages/Sphinx-1.5.1-py3.6.egg',
#  '/home/ayla/anaconda3/lib/python3.6/site-packages/IPython/extensions',
#  '/home/ayla/.ipython']
